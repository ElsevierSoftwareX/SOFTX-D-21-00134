# %%
from emipy import rawdata
from emipy import processdata

# %%
rawdata.change_rootpath('C:\\Witthaut\\presentation\\emipypresentation')

# %%
db = processdata.read_db()

db.head()
# Out:
#    FacilityReportID  PollutantReleaseAndTransferReportID  FacilityID  \
# 0              1856                                    1        5763
# 1              1856                                    1        5763
# 2              1856                                    1        5763
# 3              1856                                    1        5763
# 4              1857                                    1        5764
#
#    NationalID ParentCompanyName                                 FacilityName  \
# 0  1013410312        Lenzing AG                                   Lenzing AG
# 1  1013410312        Lenzing AG                                   Lenzing AG
# 2  1013410312        Lenzing AG                                   Lenzing AG
# 3  1013410312        Lenzing AG                                   Lenzing AG
# 4  1013410313        Lenzing AG  Wasserreinhalteverband Lenzing - Lenzing AG
#
#      StreetName BuildingNumber     City PostalCode  ...  \
# 0  Werkstraße 1            NaN  Lenzing       4860  ...
# 1  Werkstraße 1            NaN  Lenzing       4860  ...
# 2  Werkstraße 1            NaN  Lenzing       4860  ...
# 3  Werkstraße 1            NaN  Lenzing       4860  ...
# 4  Werkstraße 1            NaN  Lenzing       4860  ...
#
#                 PollutantName PollutantGroupCode    PollutantGroupName  \
# 0   Particulate matter (PM10)              INORG  Inorganic substances
# 1    Sulphur oxides (SOx/SO2)             OTHGAS           Other gases
# 2        Carbon dioxide (CO2)             GRHGAS      Greenhouse gases
# 3   Nitrogen oxides (NOx/NO2)             OTHGAS           Other gases
# 4  Zinc and compounds (as Zn)             HEVMET          Heavy metals
#
#    PollutantCAS MethodBasisCode MethodBasisName TotalQuantity  \
# 0           NaN               E       Estimated       68200.0
# 1           NaN               M        Measured      420000.0
# 2      124-38-9               E       Estimated   182000000.0
# 3           NaN               M        Measured      818000.0
# 4           NaN               M        Measured        3210.0
#
#   AccidentalQuantity UnitCode  UnitName
# 0                0.0      KGM  kilogram
# 1                0.0      KGM  kilogram
# 2                0.0      KGM  kilogram
# 3                0.0      KGM  kilogram
# 4                0.0      KGM  kilogram
#
# [5 rows x 73 columns]

# %%
db.columns
# Out:
# Index(['FacilityReportID', 'PollutantReleaseAndTransferReportID', 'FacilityID',
#        'NationalID', 'ParentCompanyName', 'FacilityName', 'StreetName',
#        'BuildingNumber', 'City', 'PostalCode', 'CountryCode', 'CountryName',
#        'Lat', 'Long', 'RBDGeoCode', 'RBDGeoName', 'NUTSRegionGeoCode',
#        'NUTSRegionGeoName', 'RBDSourceCode', 'RBDSourceName',
#        'NUTSRegionSourceCode', 'NUTSRegionSourceName',
#        'NACEMainEconomicActivityCode', 'NACEMainEconomicActivityName',
#        'CompetentAuthorityName', 'CompetentAuthorityAddressStreetName',
#        'CompetentAuthorityAddressBuildingNumber',
#        'CompetentAuthorityAddressCity', 'CompetentAuthorityAddressPostalCode',
#        'CompetentAuthorityAddressCountryCode',
#        'CompetentAuthorityAddressCountryName',
#        'CompetentAuthorityTelephoneCommunication',
#        'CompetentAuthorityFaxCommunication',
#        'CompetentAuthorityEmailCommunication',
#        'CompetentAuthorityContactPersonName', 'ProductionVolumeProductName',
#        'ProductionVolumeQuantity', 'ProductionVolumeUnitCode',
#        'ProductionVolumeUnitName', 'TotalIPPCInstallationQuantity',
#        'OperatingHours', 'TotalEmployeeQuantity', 'WebsiteCommunication',
#        'PublicInformation', 'ConfidentialIndicator',
#        'ConfidentialityReasonCode', 'ConfidentialityReasonName',
#        'ProtectVoluntaryData', 'MainIASectorCode', 'MainIASectorName',
#        'MainIAActivityCode', 'MainIAActivityName', 'MainIASubActivityCode',
#        'MainIASubActivityName', 'ReportingYear', 'CoordinateSystemCode',
#        'CoordinateSystemName', 'CdrReleased', 'Published',
#        'PollutantReleaseID', 'ReleaseMediumCode', 'ReleaseMediumName',
#        'PollutantCode', 'PollutantName', 'PollutantGroupCode',
#        'PollutantGroupName', 'PollutantCAS', 'MethodBasisCode',
#        'MethodBasisName', 'TotalQuantity', 'AccidentalQuantity', 'UnitCode',
#        'UnitName'],
#       dtype='object')

# %%
processdata.get_Countrylist(db)
# Out:
# ['Austria',
#  'Belgium',
#  'Cyprus',
#  'Czech Republic',
#  'Germany',
#  'Denmark',
#  'Estonia',
#  'Spain',
#  'Finland',
#  'France',
#  'Greece',
#  'Hungary',
#  'Ireland',
#  'Italy',
#  'Lithuania',
#  'Luxembourg',
#  'Latvia',
#  'Malta',
#  'Netherlands',
#  'Norway',
#  'Poland',
#  'Portugal',
#  'Sweden',
#  'Slovenia',
#  'Slovakia',
#  'United Kingdom',
#  'Iceland',
#  'Serbia',
#  'Romania',
#  'Bulgaria',
#  'Switzerland',
#  'Croatia']

# %%
processdata.get_Yearlist(db)
# Out:
# [2001, 2004, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]

# %%
processdata.get_Pollutantlist(db)
# Out:
# ['Particulate matter (PM10)',
#  'Sulphur oxides (SOx/SO2)',
#  'Carbon dioxide (CO2)',
#  'Nitrogen oxides (NOx/NO2)',
#  'Zinc and compounds (as Zn)',
#  'Nickel and compounds (as Ni)',
#  'Chlorides (as total Cl)',
#  'Fluorides (as total F)',
#  'Total organic carbon (TOC) (as total C or COD/3)',
#  'Halogenated organic compounds (as AOX)',
#  'Non-methane volatile organic compounds (NMVOC)',
#  'Carbon monoxide (CO)',
#  'Ammonia (NH3)',
#  'Copper and compounds (as Cu)',
#  'Nitrous oxide (N2O)',
#  'Mercury and compounds (as Hg)',
#  'Total phosphorus',
#  'Methane (CH4)',
#  'Lead and compounds (as Pb)',
#  'Hydrogen cyanide (HCN)',
#  'Chlorine and inorganic compounds (as HCl)',
#  'Benzene',
#  'Cadmium and compounds (as Cd)',
#  'Total nitrogen',
#  'Cyanides (as total CN)',
#  'Chromium and compounds (as Cr)',
#  '1,2-dichloroethane (DCE)',
#  'Phenols (as total C)',
#  'Arsenic and compounds (as As)',
#  'PCDD + PCDF (dioxins + furans) (as Teq)',
#  'Polycyclic Aromatic Hydrocarbons (PAH in EPER)',
#  'BTEX',
#  'Fluorine and inorganic compounds (as HF)',
#  'Dichloromethane (DCM)',
#  'Trichloroethylene',
#  'Tetrachloroethylene (PER)',
#  'Tetrachloromethane (TCM)',
#  'Hexachlorobenzene (HCB)',
#  'Hexachlorobutadiene (HCBD)',
#  'Trichloromethane',
#  'Hydro-fluorocarbons (HFCs)',
#  'Trichlorobenzenes (TCBs) (all isomers)',
#  'Sulphur hexafluoride (SF6)',
#  'Perfluorocarbons (PFCs)',
#  '1,1,1-trichloroethane',
#  '1,2,3,4,5,6-hexachlorocyclohexane (HCH)',
#  'Organotin compounds (as total Sn)',
#  'Chloro-alkanes, C10-C13',
#  'Polycyclic aromatic hydrocarbons (PAHs)',
#  'Di-(2-ethyl hexyl) phthalate (DEHP)',
#  'Hydrochlorofluorocarbons(HCFCs)',
#  'Chlorofluorocarbons (CFCs)',
#  'Polychlorinated biphenyls (PCBs)',
#  'Naphthalene',
#  'Carbon dioxide (CO2) excluding biomass',
#  'Atrazine',
#  'Vinyl chloride',
#  'Lindane',
#  'Fluoranthene',
#  '1,1,2,2-tetrachloroethane',
#  'Nonylphenol and Nonylphenol ethoxylates (NP/NPEs)',
#  'Octylphenols and Octylphenol ethoxylates',
#  'Xylenes',
#  'Ethylene oxide',
#  'Tributyltin and compounds',
#  'Anthracene',
#  'Triphenyltin and compounds',
#  'Pentachlorobenzene',
#  'Toluene',
#  'Diuron',
#  'Asbestos',
#  'Pentachlorophenol (PCP)',
#  'Ethyl benzene',
#  'Halons',
#  'Simazine',
#  'Trifluralin',
#  'Chlorfenvinphos',
#  'Benzo(g,h,i)perylene',
#  'Aldrin',
#  'Isodrin',
#  'Dieldrin',
#  'Endrin',
#  'Isoproturon',
#  'Brominated diphenylethers (PBDE)',
#  'Chlorpyrifos',
#  'Endosulphan',
#  'Alachlor',
#  'Hexabromobiphenyl',
#  'DDT',
#  'Chlordecone',
#  'Toxaphene',
#  'Mirex',
#  'Heptachlor',
#  'Chlordane']

# %%
data1 = processdata.f_db(db,CountryName='Germany')


data1.head()
# Out:
#       FacilityReportID  PollutantReleaseAndTransferReportID  FacilityID  \
# 3683             11100                                    7        1345
# 3684             11100                                    7        1345
# 3685             11101                                    7        1347
# 3686             11101                                    7        1347
# 3687             11101                                    7        1347
#
#              NationalID                       ParentCompanyName  \
# 3683  06-01-01000004838               Stadtwerke Flensburg GmbH
# 3684  06-01-01000004838               Stadtwerke Flensburg GmbH
# 3685  06-01-02000283604  Gemeinschaftskraftwerk Kiel GmbH -GKK-
# 3686  06-01-02000283604  Gemeinschaftskraftwerk Kiel GmbH -GKK-
# 3687  06-01-02000283604  Gemeinschaftskraftwerk Kiel GmbH -GKK-
#
#                                 FacilityName       StreetName BuildingNumber  \
# 3683               Stadtwerke Flensburg GmbH  Batteriestr. 48            NaN
# 3684               Stadtwerke Flensburg GmbH  Batteriestr. 48            NaN
# 3685  Gemeinschaftskraftwerk Kiel GmbH -GKK-   Hasselfelde 40            NaN
# 3686  Gemeinschaftskraftwerk Kiel GmbH -GKK-   Hasselfelde 40            NaN
# 3687  Gemeinschaftskraftwerk Kiel GmbH -GKK-   Hasselfelde 40            NaN
#
#            City PostalCode  ...                              PollutantName  \
# 3683  Flensburg      24939  ...                   Sulphur oxides (SOx/SO2)
# 3684  Flensburg      24939  ...                  Nitrogen oxides (NOx/NO2)
# 3685       Kiel      24149  ...  Chlorine and inorganic compounds (as HCl)
# 3686       Kiel      24149  ...                  Nitrogen oxides (NOx/NO2)
# 3687       Kiel      24149  ...                   Sulphur oxides (SOx/SO2)
#
#      PollutantGroupCode  PollutantGroupName  PollutantCAS MethodBasisCode  \
# 3683             OTHGAS         Other gases           NaN               E
# 3684             OTHGAS         Other gases           NaN               E
# 3685             OTHGAS         Other gases           NaN               M
# 3686             OTHGAS         Other gases           NaN               M
# 3687             OTHGAS         Other gases           NaN               M
#
#      MethodBasisName TotalQuantity AccidentalQuantity UnitCode  UnitName
# 3683       Estimated      582000.0                0.0      KGM  kilogram
# 3684       Estimated      378000.0                0.0      KGM  kilogram
# 3685        Measured       41000.0                0.0      KGM  kilogram
# 3686        Measured     1500000.0                0.0      KGM  kilogram
# 3687        Measured      960000.0                0.0      KGM  kilogram
#
# [5 rows x 73 columns]

# %%
data2 = processdata.f_db(db, CountryName=['Germany', 'Switzerand', 'Austria'])
data2.head()
# Out:
#    FacilityReportID  PollutantReleaseAndTransferReportID  FacilityID  \
# 0              1856                                    1        5763
# 1              1856                                    1        5763
# 2              1856                                    1        5763
# 3              1856                                    1        5763
# 4              1857                                    1        5764
#
#    NationalID ParentCompanyName                                 FacilityName  \
# 0  1013410312        Lenzing AG                                   Lenzing AG
# 1  1013410312        Lenzing AG                                   Lenzing AG
# 2  1013410312        Lenzing AG                                   Lenzing AG
# 3  1013410312        Lenzing AG                                   Lenzing AG
# 4  1013410313        Lenzing AG  Wasserreinhalteverband Lenzing - Lenzing AG
#
#      StreetName BuildingNumber     City PostalCode  ...  \
# 0  Werkstraße 1            NaN  Lenzing       4860  ...
# 1  Werkstraße 1            NaN  Lenzing       4860  ...
# 2  Werkstraße 1            NaN  Lenzing       4860  ...
# 3  Werkstraße 1            NaN  Lenzing       4860  ...
# 4  Werkstraße 1            NaN  Lenzing       4860  ...
#
#                 PollutantName PollutantGroupCode    PollutantGroupName  \
# 0   Particulate matter (PM10)              INORG  Inorganic substances
# 1    Sulphur oxides (SOx/SO2)             OTHGAS           Other gases
# 2        Carbon dioxide (CO2)             GRHGAS      Greenhouse gases
# 3   Nitrogen oxides (NOx/NO2)             OTHGAS           Other gases
# 4  Zinc and compounds (as Zn)             HEVMET          Heavy metals
#
#    PollutantCAS MethodBasisCode MethodBasisName TotalQuantity  \
# 0           NaN               E       Estimated       68200.0
# 1           NaN               M        Measured      420000.0
# 2      124-38-9               E       Estimated   182000000.0
# 3           NaN               M        Measured      818000.0
# 4           NaN               M        Measured        3210.0
#
#   AccidentalQuantity UnitCode  UnitName
# 0                0.0      KGM  kilogram
# 1                0.0      KGM  kilogram
# 2                0.0      KGM  kilogram
# 3                0.0      KGM  kilogram
# 4                0.0      KGM  kilogram
#
# [5 rows x 73 columns]

# %% [markdown]
# # Tutorial 2

# %%
from emipy import processdata
from emipy import visualizedata
import matplotlib.pyplot as plt

db = processdata.read_db()

CountryName = ['Germany', 'Austria', 'Switzerland']
ReportingYear = [2014, 2015, 2016, 2017]
PollutantName = ['Carbon dioxide (CO2)']

data1 = processdata.f_db(db, CountryName=CountryName, ReportingYear=ReportingYear, PollutantName=PollutantName)

# %%
visualizedata.plot_PollutantVolume(data1, FirstOrder='ReportingYear')
plt.savefig('C:\\Witthaut\\tests\\2020-10-01\\docs\\source\\pictures\\Tut2pic1.svg', dpi=None, facecolor='w', edgecolor='w')

# %%
visualizedata.plot_PollutantVolume(data1, FirstOrder='ReportingYear', SecondOrder='CountryName')
plt.savefig('C:\\Witthaut\\tests\\2020-10-01\\docs\\source\\pictures\\Tut2pic2.svg', dpi=None, facecolor='w', edgecolor='w')

# %%
data2 = processdata.f_db(data1, CountryName='Austria')
visualizedata.plot_PollutantVolume(data2, FirstOrder='ReportingYear')
plt.savefig('C:\\Witthaut\\tests\\2020-10-01\\docs\\source\\pictures\\Tut2pic3.svg', dpi=None, facecolor='w', edgecolor='w')

# %%
visualizedata.plot_PollutantVolumeChange(data1, FirstOrder='ReportingYear', SecondOrder='CountryName')
plt.savefig('C:\\Witthaut\\tests\\2020-10-01\\docs\\source\\pictures\\Tut2pic4.svg', dpi=None, facecolor='w', edgecolor='w')

# %%
CountryName = ['Germany', 'Austria', 'Switzerland']
ReportingYear = [2014, 2015, 2016, 2017]
PollutantName=['Zinc and compounds (as Zn)', 'Nickel and compounds (as Ni)']

data2 = processdata.f_db(db,CountryName=CountryName, ReportingYear=ReportingYear, PollutantName=PollutantName)

# %%
visualizedata.plot_PollutantVolume_rel(data2, FirstOrder='PollutantName', SecondOrder='ReportingYear')
plt.savefig('C:\\Witthaut\\tests\\2020-10-01\\docs\\source\\pictures\\Tut2pic5.svg', dpi=None, facecolor='w', edgecolor='w')

# %%
import matplotlib.pyplot as plt

# %%
fig1, fig1_axes = plt.subplots(2, 2)
fig1_axes[0,0] = visualizedata.plot_PollutantVolume(data1, FirstOrder='ReportingYear', ax=fig1_axes[0,0])
fig1_axes[1,0] = visualizedata.plot_PollutantVolume_rel(data1, FirstOrder='ReportingYear', ax=fig1_axes[1,0])
fig1_axes[0,1] = visualizedata.plot_PollutantVolumeChange(data1, FirstOrder='ReportingYear', ax=fig1_axes[0,1])
fig1_axes[1,1] = visualizedata.plot_PollutantVolume(data1, FirstOrder='ReportingYear', ax=fig1_axes[1,1], color='r')
fig1_axes[0,0].set_xlabel('Year', fontsize=20)
fig1.set_figheight(12)
fig1.set_figwidth(15)
fig1_axes[1,1].set(xlabel='Year', ylabel='Emission [kg]')
plt.show()

fig1.savefig('C:\\Witthaut\\tests\\2020-10-01\\docs\\source\\pictures\\Tut2pic6.svg', dpi=None, facecolor='w', edgecolor='w')

# %% [markdown]
# # Using map data

# %%
from emipy import processdata
from emipy import visualizedata
mb = processdata.read_mb()
mb.plot()
#plt.savefig('C:\\Witthaut\\tests\\2020-10-01\\docs\\source\\pictures\\Tut3pic1.svg', dpi=None, facecolor='w', edgecolor='w')
# Out:
# <AxesSubplot:>

# %%
NUTS_LVL = '1'
Resolution = '01M'
datatype = 'shp'
projection = '4326'
spatialtype = 'RG'
m_year = '2021'


mb = processdata.read_mb(Resolution=Resolution, spatialtype=spatialtype, NUTS_LVL=NUTS_LVL, m_year=m_year, projection=projection)
mb.plot()
plt.savefig('C:\\Witthaut\\tests\\2020-10-01\\docs\\source\\pictures\\Tut3pic1.svg', dpi=None, facecolor='w', edgecolor='w')

# %%
mapdata1 = processdata.f_mb(mb, ExclaveExclude=True)
mapdata1.plot()
plt.savefig('C:\\Witthaut\\tests\\2020-10-01\\docs\\source\\pictures\\Tut3pic2.svg', dpi=None, facecolor='w', edgecolor='w')

# %%
mapdata2 = processdata.f_mb(mb, CNTR_CODE='DE')
mapdata2.plot()
plt.savefig('C:\\Witthaut\\tests\\2020-10-01\\docs\\source\\pictures\\Tut3pic3.svg', dpi=None, facecolor='w', edgecolor='w')

# %%
mapdata3 = processdata.f_mb(mb, NUTS_ID=['DEA'], CNTR_CODE='DE')
mapdata3.plot(aspect='equal')
plt.savefig('C:\\Witthaut\\tests\\2020-10-01\\docs\\source\\pictures\\Tut3pic4.svg', dpi=None, facecolor='w', edgecolor='w')

# %%
import matplotlib.pyplot as plt

CountryName = ['Germany', 'Austria']
ReportingYear = [2017]
PollutantName = ['Carbon dioxide (CO2)']



data4 = processdata.f_db(db,CountryName=CountryName, ReportingYear=ReportingYear, PollutantName=PollutantName)
mapdata4 = processdata.f_mb(mb, CNTR_CODE=['DE','AT'])

fig1 = plt.figure()
ax1 = fig1.add_subplot(1, 1, 1)
#ax1 = mapdata1.plot(ax=ax1, color='lightgrey')
ax1 = visualizedata.map_PollutantSource(data4, mapdata4, markersize=200, ax=ax1)
fig1.set_figheight(10)
fig1.set_figwidth(10)

fig1.savefig('C:\\Witthaut\\tests\\2020-10-01\\docs\\source\\pictures\\Tut3pic5.svg', dpi=None, facecolor='w', edgecolor='w')
# Out:
# All data points are within rectangular borders

# %%
CountryName = ['Germany', 'Austria']
ReportingYear = [2017]
PollutantName = ['Carbon dioxide (CO2)', 'Nitrogen oxides (NOx/NO2)']



data5 = processdata.f_db(db,CountryName=CountryName, ReportingYear=ReportingYear, PollutantName=PollutantName)
mapdata5 = processdata.f_mb(mb, CNTR_CODE=['DE','AT'])

fig2 = plt.figure()
ax1 = fig2.add_subplot(1, 1, 1)
ax1 = visualizedata.map_PollutantSource(data5, mapdata5, markersize=200, category='PollutantName', ax=ax1)
fig2.set_figheight(10)
fig2.set_figwidth(10)

fig2.savefig('C:\\Witthaut\\tests\\2020-10-01\\docs\\source\\pictures\\Tut3pic6.svg', dpi=None, facecolor='w', edgecolor='w')
# Out:
# All data points are within rectangular borders

# %%
NUTS_LVL = '2'
Resolution = '01M'
datatype = 'shp'
projection = '4326'
spatialtype = 'RG'
m_year = '2021'

mb = processdata.read_mb(Resolution=Resolution, spatialtype=spatialtype, NUTS_LVL=NUTS_LVL, m_year=m_year, projection=projection)


CountryName = ['Austria']
ReportingYear = [2017]
PollutantName = ['Carbon dioxide (CO2)']

data6 = processdata.f_db(db,CountryName=CountryName, ReportingYear=ReportingYear, PollutantName=PollutantName)
mapdata6 = processdata.f_mb(mb, CNTR_CODE='AT')

fig3 = plt.figure()
ax1 = fig3.add_subplot(1, 1, 1)
ax1 = visualizedata.map_PollutantRegions(data6, mapdata6, ax=ax1, legend=True)
fig3.set_figheight(10)
fig3.set_figwidth(10)

fig3.savefig('C:\\Witthaut\\tests\\2020-10-01\\docs\\source\\pictures\\Tut3pic7.svg', dpi=None, facecolor='w', edgecolor='w')
